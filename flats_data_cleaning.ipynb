# %% [markdown]
# <a href="https://colab.research.google.com/github/2002hk/housing_price_capstone/blob/main/flats_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
df=pd.read_csv('/content/flats - flats.csv')
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#               area                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3009 entries, 0 to 3008
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3009 non-null   object
#  1   society          3008 non-null   object
#  2   price            3008 non-null   object
#  3   area             2997 non-null   object
#  4   areaWithType     3009 non-null   object
#  5   bedRoom          3009 non-null   object
#  6   bathroom         3009 non-null   object
#  7   balcony          3009 non-null   object
#  8   additionalRoom   1695 non-null   object
#  9   address          3003 non-null   object
#  10  floorNum         3007 non-null   object
#  11  facing           2128 non-null   object
#  12  agePossession    3008 non-null   object
#  13  nearbyLocations  2914 non-null   object
#  14  description      3009 non-null   object
#  15  furnishDetails   2204 non-null   object
# ...

# %% [markdown]
# ##Columns Information
# - property_name: no of bhk and name of the area in which the property is located
# - society: name of the colony or society
# - price: price of property in lac,crores
# - area: it contains price per square feet
# - areawithType: carpet Area, built-up area, super built-up area
# - bedRoom: no of bedrooms
# - bathroom: no of bathrooms
# - balcny: no of balcony
# - additionalRoom: studyroom, poojaroom, storeroom, servantroom,others
# - address: location of the property
# - floorNum: situated on which floor
# - facing: front door facing which direction
# - agePossession: how old is the property
# - nearbyLocations: nearby landmarks
# - descriptions: informations about the property
# - furnishDetails: no of fans, ac, wardrobe etc.
# - features: features like fire alarm, garden, playarea etc inside a colony or the building
# - property_id: unique property id

# %%
df.shape
# Out:
# (3009, 18)

# %%
#checking ofr duplicates
df.duplicated().sum()
# Out:
# 125

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (2884, 18)

# %%
df.isnull().sum()
# Out:
# property_name         0
# society               1
# price                 1
# area                 11
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom     1239
# address               6
# floorNum              2
# facing              821
# agePossession         1
# nearbyLocations      87
# description           0
# furnishDetails      769
# features            375
# property_id           0
# dtype: int64

# %%
#rename colums
df.rename(columns={'area':'price_per_sqft'},inplace=True)
# Out:
# <ipython-input-105-452804b326e6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'area':'price_per_sqft'},inplace=True)

# %%
df['society'].value_counts()
# Out:
# society
# SS The Leaf3.8 ★                                     72
# Tulip Violet4.3 ★                                    40
# Shapoorji Pallonji Joyville Gurugram4.0 ★            38
# Signature Global Park4.0 ★                           34
# Shree Vardhman Victoria3.8 ★                         34
# Tulip Violet4.2 ★                                    33
# Emaar MGF Emerald Floors Premier3.8 ★                32
# Smart World Orchard                                  32
# DLF The Ultima4.0 ★                                  31
# Paras Dews                                           31
# DLF Regal Gardens3.9 ★                               30
# M3M Woodshire4.0 ★                                   29
# Shree Vardhman Flora3.8 ★                            29
# La Vida by Tata Housing                              28
# Smart World Gems                                     27
# Godrej Nature Plus                                   27
# Signature Global Solera3.7 ★                         27
# ...

# %%
df['price'].value_counts()
# Out:
# price
# 1.25 Crore          76
# 1.4 Crore           58
# 1.2 Crore           57
# 1.1 Crore           57
# 1.5 Crore           57
# 1.3 Crore           54
# 90 Lac              53
# 2 Crore             47
# 1.75 Crore          47
# 95 Lac              47
# 1.6 Crore           43
# 1 Crore             41
# 1.35 Crore          40
# 1.55 Crore          39
# 1.65 Crore          37
# 1.8 Crore           37
# 1.9 Crore           36
# 1.7 Crore           35
# 80 Lac              35
# 75 Lac              33
# 50 Lac              32
# 2.2 Crore           31
# 1.15 Crore          31
# 1.45 Crore          30
# 2.5 Crore           29
# 85 Lac              29
# 1.05 Crore          28
# 60 Lac              28
# 2.1 Crore           26
# 40 Lac              25
# 45 Lac              25
# 65 Lac              24
# 2.35 Crore          23
# 1.85 Crore          23
# 70 Lac              21
# 3 Crore             20
# 35 Lac              20
# 2.25 Crore          20
# 55 Lac              19
# ...

# %%
df['price_per_sqft'].value_counts()
# Out:
# price_per_sqft
# ₹ 10,000/sq.ft.     18
# ₹ 8,000/sq.ft.      16
# ₹ 5,000/sq.ft.      13
# ₹ 12,500/sq.ft.     13
# ₹ 6,666/sq.ft.      12
# ₹ 6,000/sq.ft.      11
# ₹ 8,333/sq.ft.      11
# ₹ 7,500/sq.ft.      10
# ₹ 8,461/sq.ft.       9
# ₹ 9,000/sq.ft.       7
# ₹ 7,000/sq.ft.       7
# ₹ 12,000/sq.ft.      7
# ₹ 6,578/sq.ft.       6
# ₹ 8,928/sq.ft.       6
# ₹ 11,500/sq.ft.      6
# ₹ 16,000/sq.ft.      5
# ₹ 8,571/sq.ft.       5
# ₹ 7,641/sq.ft.       5
# ₹ 4,615/sq.ft.       5
# ₹ 5,500/sq.ft.       5
# ₹ 7,407/sq.ft.       5
# ₹ 8,205/sq.ft.       5
# ₹ 8,888/sq.ft.       5
# ₹ 6,500/sq.ft.       5
# ₹ 11,111/sq.ft.      5
# ₹ 7,692/sq.ft.       5
# ₹ 7,142/sq.ft.       5
# ₹ 9,230/sq.ft.       5
# ₹ 14,242/sq.ft.      5
# ₹ 11,428/sq.ft.      5
# ₹ 5,600/sq.ft.       5
# ₹ 5,660/sq.ft.       4
# ₹ 8,784/sq.ft.       4
# ₹ 4,500/sq.ft.       4
# ₹ 9,822/sq.ft.       4
# ₹ 7,317/sq.ft.       4
# ₹ 9,210/sq.ft.       4
# ₹ 6,250/sq.ft.       4
# ₹ 14,418/sq.ft.      4
# ...

# %%
df=df[df['price']!='Price on Request']

# %%
df['price']
# Out:
# 0            45 Lac
# 1            50 Lac
# 2            40 Lac
# 3        1.47 Crore
# 4            70 Lac
# 5            41 Lac
# 6           2 Crore
# 7         1.8 Crore
# 8         1.1 Crore
# 9        4.75 Crore
# 10           96 Lac
# 11           29 Lac
# 12       1.35 Crore
# 13           95 Lac
# 14           70 Lac
# 15       3.95 Crore
# 16           90 Lac
# 17       1.05 Crore
# 18              NaN
# 19        2.2 Crore
# 20       1.01 Crore
# 21       1.85 Crore
# 22           86 Lac
# 23       1.85 Crore
# 24       2.85 Crore
# 26           42 Lac
# 27       6.15 Crore
# 28       6.25 Crore
# 29           42 Lac
# 30       1.35 Crore
# 31        1.6 Crore
# 32       3.25 Crore
# 33           45 Lac
# 34           85 Lac
# 35           75 Lac
# 36           82 Lac
# 37        1.8 Crore
# 38        29.99 Lac
# 39           78 Lac
# 40          2 Crore
# 41           74 Lac
# 42        3.2 Crore
# 43        1.3 Crore
# 44           25 Lac
# 45           95 Lac
# ...

# %%
#converting price to crores
def price_to_cr(x):
    # Check if the price is in 'Lac' or 'Crore' and convert accordingly
    try:
        if x[1] == 'Lac':
            # Convert Lac to base (e.g., in lakhs)
            return round(float(x[0]), 2)  # Keep as is, since 1 Lac = 1,00,000
        elif x[1] == 'Crore':
            # Convert Crore to base (e.g., multiply by 100, as 1 Crore = 100 Lac)
            return round(float(x[0]) * 100, 2)
    except (ValueError, IndexError):
        # Handle cases where conversion fails or unexpected format
        return None

# %%
df.dropna(subset=['price'], inplace=True)

# %%
df['price'].str.split(' ')
# Out:
# 0            [45, Lac]
# 1            [50, Lac]
# 2            [40, Lac]
# 3        [1.47, Crore]
# 4            [70, Lac]
# 5            [41, Lac]
# 6           [2, Crore]
# 7         [1.8, Crore]
# 8         [1.1, Crore]
# 9        [4.75, Crore]
# 10           [96, Lac]
# 11           [29, Lac]
# 12       [1.35, Crore]
# 13           [95, Lac]
# 14           [70, Lac]
# 15       [3.95, Crore]
# 16           [90, Lac]
# 17       [1.05, Crore]
# 19        [2.2, Crore]
# 20       [1.01, Crore]
# 21       [1.85, Crore]
# 22           [86, Lac]
# 23       [1.85, Crore]
# 24       [2.85, Crore]
# 26           [42, Lac]
# 27       [6.15, Crore]
# 28       [6.25, Crore]
# 29           [42, Lac]
# 30       [1.35, Crore]
# 31        [1.6, Crore]
# 32       [3.25, Crore]
# 33           [45, Lac]
# 34           [85, Lac]
# 35           [75, Lac]
# 36           [82, Lac]
# 37        [1.8, Crore]
# 38        [29.99, Lac]
# 39           [78, Lac]
# 40          [2, Crore]
# 41           [74, Lac]
# ...

# %%
#fetching price value
df['price']=df['price'].str.split(' ').apply(price_to_cr)
df['price']
# Out:
# 0         45.00
# 1         50.00
# 2         40.00
# 3        147.00
# 4         70.00
# 5         41.00
# 6        200.00
# 7        180.00
# 8        110.00
# 9        475.00
# 10        96.00
# 11        29.00
# 12       135.00
# 13        95.00
# 14        70.00
# 15       395.00
# 16        90.00
# 17       105.00
# 19       220.00
# 20       101.00
# 21       185.00
# 22        86.00
# 23       185.00
# 24       285.00
# 26        42.00
# 27       615.00
# 28       625.00
# 29        42.00
# 30       135.00
# 31       160.00
# 32       325.00
# 33        45.00
# 34        85.00
# 35        75.00
# 36        82.00
# 37       180.00
# 38        29.99
# 39        78.00
# 40       200.00
# 41        74.00
# 42       320.00
# 43       130.00
# 44        25.00
# 45        95.00
# 46       199.00
# 47       105.00
# 48       183.00
# 49       225.00
# 50       280.00
# 51       160.00
# 52        83.00
# 53        83.00
# 54        80.00
# 55       125.00
# 56        23.00
# ...

# %%
#fetching price per square feet value
df['price_per_sqft'] = (
    df['price_per_sqft']
    .str.split('/').str.get(0)   # Split on '/' and get the first part
    .str.replace('₹', '')        # Remove the '₹' symbol
    .str.replace(',', '')        # Remove commas from the numeric strings
    .str.strip()                 # Strip any leading/trailing whitespace
)

# Convert to float, coercing errors (non-convertible strings will become NaN)
df['price_per_sqft'] = pd.to_numeric(df['price_per_sqft'], errors='coerce')

# Display rows with NaN (optional, to inspect invalid entries)

# %%
df[df['price_per_sqft'].isna()]
# Out:
#      property_name  society  price  price_per_sqft  areaWithType  bedRoom  \
# 286  property_name  society    NaN             NaN  areaWithType  bedRoom
#
#      bathroom  balcony  additionalRoom  address  floorNum  facing  \
# 286  bathroom  balcony  additionalRoom  address  floorNum  facing
#
#      agePossession  nearbyLocations  description  furnishDetails  features  \
# 286  agePossession  nearbyLocations  description  furnishDetails  features
#
#      property_id
# 286  property_id

# %%
df['price_per_sqft']
# Out:
# 0         5000.0
# 1         7692.0
# 2         6722.0
# 3        12250.0
# 4         5204.0
# 5         6269.0
# 6        13333.0
# 7         7860.0
# 8         8148.0
# 9        16885.0
# 10        9767.0
# 11        5587.0
# 12        6940.0
# 13        6859.0
# 14        5384.0
# 15       16859.0
# 16       14084.0
# 17       11475.0
# 19       10476.0
# 20        9156.0
# 21        8604.0
# 22        7796.0
# 23        9135.0
# 24       12855.0
# 26        7910.0
# 27       18331.0
# 28       24300.0
# 29        5600.0
# 30       12784.0
# 31       26936.0
# 32       10156.0
# 33        7194.0
# 34        6538.0
# 35        5769.0
# 36        6950.0
# 37        8866.0
# 38        5403.0
# 39        5714.0
# 40       15151.0
# 41        6200.0
# 42       16000.0
# 43        6378.0
# 44        3571.0
# 45        7846.0
# 46        7297.0
# 47        7581.0
# 48       10005.0
# 49       10714.0
# 50       16969.0
# 51       14545.0
# 52        5424.0
# 53        7410.0
# ...

# %%
df[df['bedRoom'].isnull()]
# Out:
# Empty DataFrame
# Columns: [property_name, society, price, price_per_sqft, areaWithType, bedRoom, bathroom, balcony, additionalRoom, address, floorNum, facing, agePossession, nearbyLocations, description, furnishDetails, features, property_id]
# Index: []

# %%
df['bathroom'].isnull().sum()
# Out:
# 0

# %%
df['balcony'].isnull().sum()
# Out:
# 0

# %%
df['bedRoom']=df['bedRoom'].str.split(' ').str.get(0).str.strip()

# %%
df['bedRoom']=df['bedRoom'].dropna()
df['bedRoom'] = pd.to_numeric(df['bedRoom'], errors='coerce')
df['bedRoom']=df['bedRoom'].dropna()

# %%
df = df.drop(286, axis=0)  # Drops the row with index 5

# %%
df[df['bedRoom'].isna()]
# Out:
# Empty DataFrame
# Columns: [property_name, society, price, price_per_sqft, areaWithType, bedRoom, bathroom, balcony, additionalRoom, address, floorNum, facing, agePossession, nearbyLocations, description, furnishDetails, features, property_id]
# Index: []

# %%
df['bedRoom'] = df['bedRoom'].astype('int')
df['bedRoom'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: bedRoom, dtype: int64

# %%
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).str.strip()
df['bathroom'] = pd.to_numeric(df['bathroom'], errors='coerce')

# %%
df['balcony'] = df['balcony'].str.split(' ').str.get(0).str.strip()
df['balcony'] = pd.to_numeric(df['balcony'], errors='coerce')

# %%
df[df['balcony'].isna()].shape
# Out:
# (921, 18)

# %%
df['balcony'].value_counts()
# Out:
# balcony
# 3.0    939
# 2.0    710
# 1.0    302
# Name: count, dtype: int64

# %%
df['balcony']=df['balcony'].fillna(0)

# %%
df['bathroom'] = df['bathroom'].astype('int')
df['bathroom'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: bathroom, dtype: int64

# %%
df['additionalRoom'].fillna('not available',inplace=True)
# Out:
# <ipython-input-132-37c81a970354>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['additionalRoom'].fillna('not available',inplace=True)

# %%
df['additionalRoom'] = df['additionalRoom'].str.lower()

# %%
df['floorNum'] = df['floorNum'].str.split(' ').str.get(0).replace('Ground','0').str.replace('Basement','-1').str.replace('Lower','0').str.extract(r'(\d+)')

# %%
df['facing'].fillna('NA',inplace=True)
# Out:
# <ipython-input-135-e6ba103970bd>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['facing'].fillna('NA',inplace=True)

# %%
df['facing'].value_counts()
# Out:
# facing
# NA            815
# North-East    488
# East          471
# North         290
# South         201
# West          178
# North-West    155
# South-East    143
# South-West    131
# Name: count, dtype: int64

# %%
df.insert(loc=4,column='area',value=round((df['price']*10000000)/df['price_per_sqft']))

# %%
df.insert(loc=1,column='property_type',value='flat')

# %%
df.head()
# Out:
#                      property_name property_type                 society  \
# 0     2 BHK Flat in Krishna Colony          flat  maa bhagwati residency
# 1        2 BHK Flat in Ashok Vihar          flat            Apna Enclave
# 2              2 BHK Flat in Sohna          flat  Tulsiani Easy in Homes
# 3  2 BHK Flat in Sector 61 Gurgaon          flat     Smart World Orchard
# 4  2 BHK Flat in Sector 92 Gurgaon          flat        Parkwood Westend
#
#    price  price_per_sqft      area                            areaWithType  \
# 0   45.0          5000.0   90000.0          Carpet area: 900 (83.61 sq.m.)
# 1   50.0          7692.0   65003.0          Carpet area: 650 (60.39 sq.m.)
# 2   40.0          6722.0   59506.0          Carpet area: 595 (55.28 sq.m.)
# 3  147.0         12250.0  120000.0        Carpet area: 1200 (111.48 sq.m.)
# 4   70.0          5204.0  134512.0  Super Built up area 1345(124.95 sq.m.)
#
#    bedRoom  bathroom  balcony additionalRoom  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2872 entries, 0 to 3008
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2872 non-null   object
#  1   property_type    2872 non-null   object
#  2   society          2871 non-null   object
#  3   price            2872 non-null   float64
#  4   price_per_sqft   2872 non-null   float64
#  5   area             2872 non-null   float64
#  6   areaWithType     2872 non-null   object
#  7   bedRoom          2872 non-null   int64
#  8   bathroom         2872 non-null   int64
#  9   balcony          2872 non-null   float64
#  10  additionalRoom   2872 non-null   object
#  11  address          2866 non-null   object
#  12  floorNum         2870 non-null   object
#  13  facing           2872 non-null   object
#  14  agePossession    2871 non-null   object
#  15  nearbyLocations  2788 non-null   object
# ...

# %%
df.shape
# Out:
# (2872, 20)

# %%
df.to_csv('flats_cleaned2.csv',index='False')
